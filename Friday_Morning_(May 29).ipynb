# %%
structure = {"qiyas_01":{"family":["betty"],"friend":["heran","tina"]}}

# %%
print(structure['qiyas_01']['friend'])
# Out:
# ['heran', 'tina']

# %%
text="The young man wanted a role model. He looked long and hard in his youth, but that role model never materialized. His only choice was to embrace all the people in his life he didn't want to be like."
#len(text.lower().split())
cleaned_text = text.replace(".","").replace(",","")
clean_list = cleaned_text.lower().split()
sorted(wordlist)
#clean_list= sorted(wordlist)
# Out:
# ['a',
#  'all',
#  'and',
#  'be',
#  'but',
#  'choice',
#  'didnt',
#  'embrace',
#  'hard',
#  'he',
#  'he',
#  'his',
#  'his',
#  'his',
#  'in',
#  'in',
#  'life',
#  'like',
#  'long',
#  'looked',
#  'man',
#  'materialized',
#  'model',
#  'model',
#  'never',
#  'only',
#  'people',
#  'role',
#  'role',
#  'that',
#  'the',
#  'the',
#  'to',
#  'to',
#  'want',
#  'wanted',
#  'was',
#  'young',
#  'youth,']

# %%
print(*clean_list)
# Out:
# the young man wanted a role model he looked long and hard in his youth but that role model never materialized his only choice was to embrace all the people in his life he didnt want to be like

# %%
counts ={}
for word in clean_list:
    if word in counts:
        counts[word] +=1
    else:
        counts[word] =1
print(counts)
# Out:
# {'the': 2, 'young': 1, 'man': 1, 'wanted': 1, 'a': 1, 'role': 2, 'model': 2, 'he': 2, 'looked': 1, 'long': 1, 'and': 1, 'hard': 1, 'in': 2, 'his': 3, 'youth': 1, 'but': 1, 'that': 1, 'never': 1, 'materialized': 1, 'only': 1, 'choice': 1, 'was': 1, 'to': 2, 'embrace': 1, 'all': 1, 'people': 1, 'life': 1, 'didnt': 1, 'want': 1, 'be': 1, 'like': 1}

# %%
import os

# %%
file = open("multt.txt","a",encoding="utf-8")

# %%
for word in counts:
    file.write(word+"\t"+str(counts[word])+"\n")
file.close()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[68], line 2
#       1 for word in counts:
# ----> 2     file.write(word+"\t"+str(counts[word])+"\n")
#       3 file.close()
#
# ValueError: I/O operation on closed file.
