# %%
# !python --version
# Out:
# Python 3.13.9

# %% [markdown]
# **Defining and printing variables**

# %%
mySuperMessage = "Hello Typhon welcome to this python course"
print(mySuperMessage)

mySuperMessage = "This is the best and fastest python course in the world"
print(mySuperMessage)
# Out:
# Hello Typhon welcome to this python course
# This is the best and fastest python course in the world

# %% [markdown]
# **Error readinging and traceback**

# %% [markdown]
# mySuperMegaMesage = "Hello Every student from Your instructor Typhon!"
# print(mySuperMegaMesage)

# %% [markdown]
# **Assignment Operator**

# %%
a = 5
b = 10
b = a
print ("a = ", a)
print ("b = ", b)
# Out:
# a =  5
# b =  5

# %% [markdown]
# # Strings

# %%
name = "this iS the worlDs best python course"
print(name.lower())
# Out:
# this is the worlds best python course

# %% [markdown]
# **Using f strings**

# %%
car_make = "BMW"
car_model = "5er 2014"
car = f"{car_make} {car_model}"
my_message = f"Typhon drives a {car.upper()}"
my_bigger_message = f"{my_message} and he crashed it"
print(my_bigger_message)
# Out:
# Typhon drives a BMW 5ER 2014 and he crashed it

# %% [markdown]
# **New lines and tabs**

# %%
print("\tProgramming Languages :\n\t\tPython\n\t\tC++\n\tJava\n\tSwift")
# Out:
# 	Programming Languages :
# 		Python
# 		C++
# 	Java
# 	Swift

# %% [markdown]
# **String manipulation**

# %%
udemy_url = 'https://udemy.com'
udemy_url_without_prefix = udemy_url.removeprefix("https://")
print(udemy_url_without_prefix)
print(udemy_url)
# Out:
# udemy.com
# https://udemy.com

# %% [markdown]
# **Single quote and double quote**

# %%
my_special_message = 'This is the fastest and BEST Pythons course in the world'
print(my_special_message)
# Out:
# This is the fastest and BEST Pythons course in the world

# %% [markdown]
# # Numbers

# %% [markdown]
# **Maths and floats**

# %%
my_val = 3 ** 2.0
print(my_val)
# Out:
# 9.0

# %% [markdown]
# # Lists

# %% [markdown]
# **Indexes, Lists and Creating Lists in Python**

# %%
myspecial_numbers = [5,11,225,65,27,12]

car_makes = ['Mercedes-Benz','BMW','VW','Honda','Kia','Hyundai']

print(f"My first car was a {car_makes[1].title()}")
# Out:
# My first car was a Bmw

# %% [markdown]
# **Popping an item from a list**

# %%
car_makers = ['Honda','BMW','VW','JEEP','Fiat','Opel','SAAB']
print(car_makers)


last_owned_car = car_makers.pop()
print(car_makers)

print(f"The last car model that Typhon owned was a {last_owned_car}")
# Out:
# ['Honda', 'BMW', 'VW', 'JEEP', 'Fiat', 'Opel', 'SAAB']
# ['Honda', 'BMW', 'VW', 'JEEP', 'Fiat', 'Opel']
# The last car model that Typhon owned was a SAAB

# %% [markdown]
# **Removing an item from a list**

# %% [markdown]
# car_makers = ['Honda','BMW','VW','JEEP','Fiat','Opel','SAAB']
# print(car_makers)
#
#
# too_expensive = 'JEEP'
# car_makers.remove(too_expensive)
# print(car_makers)
# print(f"\n A {too_expensive.title()} is too expensive for me")

# %% [markdown]
# **Sorting a list**

# %%
cars = ['bmw','audi','jeep','toyota','kia','honda']
print("This is our original List :")
print(cars)

print("\n This is a Sorted List :")
print(sorted(cars))

print("\nThis is our original List :")
print(cars)

# %% [markdown]
# **Len, Indexing Errors and Final of This Section**

# %%
cars = ['bmw','audi','jeep']
print()
print(len(cars))
# Out:
# 3

# %% [markdown]
# # Loops in python

# %% [markdown]
# **Looping with list**

# %%
car_makers = ['bmw','kia','ford','dodge','mercedes','vw']
for car_make in car_makers:
    print(car_makers)
# Out:
# ['bmw', 'kia', 'ford', 'dodge', 'mercedes', 'vw']
# ['bmw', 'kia', 'ford', 'dodge', 'mercedes', 'vw']
# ['bmw', 'kia', 'ford', 'dodge', 'mercedes', 'vw']
# ['bmw', 'kia', 'ford', 'dodge', 'mercedes', 'vw']
# ['bmw', 'kia', 'ford', 'dodge', 'mercedes', 'vw']
# ['bmw', 'kia', 'ford', 'dodge', 'mercedes', 'vw']

# %% [markdown]
# **Palying with Loops**

# %%
car_makers = ['bmw','kia','ford','dodge','mercedes','vw']
for car_make in car_makers:
    print(f"{car_make.title()} great car !" )
    print(f"Miles per gallon is high on {car_make}n")
# Out:
# Bmw great car !
# Miles per gallon is high on bmwn
# Kia great car !
# Miles per gallon is high on kian
# Ford great car !
# Miles per gallon is high on fordn
# Dodge great car !
# Miles per gallon is high on dodgen
# Mercedes great car !
# Miles per gallon is high on mercedesn
# Vw great car !
# Miles per gallon is high on vwn

# %% [markdown]
# **Possible error with loops**

# %%
car_makers = ['bmw','kia','ford','dodge','mercedes','vw']
for car_make in car_makers:
    print(f"{car_make.title()} great car ! ")
print(f"Miles per gallon is high on {car_make}\n")

print("Thank you every car makers, these cars are special and great")
# Out:
# Bmw great car !
# Kia great car !
# Ford great car !
# Dodge great car !
# Mercedes great car !
# Vw great car !
# Miles per gallon is high on vw
#
# Thank you every car makers, these cars are special and great

# %% [markdown]
# **Using Range and Loops Together**

# %%
mySquares = []

for myValue in range(1,11):# range(1,11) range of numbers 1 to 11
    mySquare = myValue ** 2
    mySquares.append(mySquare)

print(mySquares)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %% [markdown]
# **Slices in with Lists and Loops**

# %%
name= input("Enter your name : ")
# Out:
# Enter your name :  Heran

# %%
print("Hello," + name +"! Welcome!")
# Out:
# Hello,Heran! Welcome!

# %% [markdown]
# # If,else,Else if

# %%
age = 20
if age >= 18:
    print("Eligible to vote")
# Out:
# Eligible to vote

# %%
li = ["python","for","trainee"]
for index in range(len(li)):
    print(li[index])
# Out:
# python
# for
# trainee

# %%
n=4
for i in range(0,n):
    print(i)
# Out:
# 0
# 1
# 2
# 3

# %%
cnt = 0
while(cnt < 3):
  cnt = cnt +1
  print("hello python")
# Out:
# hello python
# hello python
# hello python

# %% [markdown]
# **If Else with Example**

# %%
car_model = "bmw"
car_year = 1000

if (2023 - car_year) < 10:
    print(f"Your {car_model} is {2023 - car_year} years old and its almost new we can buy it")
else:
    print(f"Sorry Our company doesn't buy {car_model} that age is more than 10")
    print(f"Your car age is {2023 - car_year}")
# Out:
# Sorry Our company doesn't buy bmw that age is more than 10
# Your car age is 1023

# %%
isLate = True
if isLate:
    print("I need to call my BOSS")
# Out:
# I need to call my BOSS

# %% [markdown]
# # Tuple

# %%
data = (1,2,3,4)

# %%
data
# Out:
# (1, 2, 3, 4)

# %%
data(2) # can not retreve a tuple
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 data(2)
#
# TypeError: 'tuple' object is not callable

# %% [markdown]
# # List

# %%
data = [1,2,3,4]

# %%
data[2]
# Out:
# 3

# %%
data[2]=2026

# %%
data
# Out:
# [1, 2, 2026, 4]

# %%
del data[2]

# %%
data
# Out:
# [1, 2, 4]

# %%
data.append(2026)

# %%
data
# Out:
# [1, 2, 4, 2026]

# %%
data.pop()
# Out:
# 2026

# %%
data
# Out:
# [1, 2, 4]

# %%
for data in data:
    print(data)
# Out:
# 1
# 2
# 4

# %%
li = ["python","java","js","R","php","sql"]
for index in range(len(li)):
    print(li[index])
# Out:
# python
# java
# js
# R
# php
# sql

# %%
li[-1] * 2 #concatenates
# Out:
# 'sqlsql'

# %%
li[2]
# Out:
# 'js'

# %%
li[-2]
# Out:
# 'php'

# %%
li[1:2]
# Out:
# ['java']

# %%
li[-3:4]
# Out:
# ['R']

# %%
#next class pandas dicts table structures no sub setting list tuple

# %% [markdown]
# # Dictionary

# %%
girl ={
    "name":["heran","tina"],
    "fav food": "cheese",
    "age":23 }

# %%
girl #multiple attributes can be attached to one key. key will override if you
# Out:
# {'name': ['heran', 'tina'], 'fav food': 'cheese', 'age': 23}

# %%
girl['name']
# Out:
# 'heran'

# %%
girl["fav movie"]= "joker"

# %%
girl
# Out:
# {'name': 'heran', 'fav food': 'cheese', 'age': 23, 'fav movie': 'joker'}

# %%
girl.pop("fav movie")
# Out:
# 'joker'

# %%
girl
# Out:
# {'name': 'heran', 'fav food': 'cheese', 'age': 23}

# %%
del girl["name"]

# %%
girl
# Out:
# {'fav food': 'cheese', 'age': 23}

# %%
for d in girl.keys:
    print(d)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 for d in girl.keys:
#       2     print(d)
#
# TypeError: 'builtin_function_or_method' object is not iterable

# %%
# Assuming wordlist is a list like ["['apple.'", "'banana'"]
word_counts = {}

for item in wordlist:
    # Strip the brackets, quotes, and periods
    cleaned_item = item.replace("'", "").replace("[", "").replace("]", "").replace(".", "")
    
    # Only count if the cleaned item isn't an empty string
    if cleaned_item:
        word_counts[cleaned_item] = word_counts.get(cleaned_item, 0) + 1

# %%
text="The young man wanted a role model. He looked long and hard in his youth, but that role model never materialized. His only choice was to embrace all the people in his life he didn't want to be like."
#len(text.lower().split())
cleaned_text = wordlist.replace("'", "").replace("[", "").replace("]", "").replace(".","")
wordlist = text.lower().split()
sorted(wordlist)
#clean_list= sorted(wordlist)
