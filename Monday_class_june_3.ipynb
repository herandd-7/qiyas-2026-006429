# %%
data = [1,2,3,4]

# %%
for value in data:
    print( value ** 2/ value )
# Out:
# 1.0
# 2.0
# 3.0
# 4.0

# %%
print([value ** 2/ value for value in data])
# Out:
# [1.0, 2.0, 3.0, 4.0]

# %%
Range_value = range(0,15)
result = [value for value in Range_value if value % 2 == 0]
print(result)
# Out:
# [0, 2, 4, 6, 8, 10, 12, 14]

# %%
c = [(x, y) for x in range(3) for y in range(3)]
print(c)
# Out:
# [(0, 0), (0, 1), (0, 2), (1, 0), (1, 1), (1, 2), (2, 0), (2, 1), (2, 2)]
