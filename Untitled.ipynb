# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
base_url = "https://www.fanabc.com/english"
categories = {
    "Local News": "/category/local-news/",
    "Business": "/category/business/",
    "Sport": "/category/sport/",
}
headers = {
    "User-Agent": "Mozilla/5.0"
}

# %%
all_articles = []
for category, path in categories.items():
    url = base_url + path
    page = requests.get(url, headers=headers)
    soup = BeautifulSoup(page.text, "html.parser")
    articles = soup.find_all("article")
    for article in articles:
        title_tag = article.find("h2", class_="title")
        link_tag = title_tag.find("a") if title_tag else None
        title = link_tag.get_text(strip=True) if link_tag else ""
        article_url = link_tag["href"] if link_tag and link_tag.has_attr("href") else ""
        all_articles.append({
            "category": category,
            "source_url": url,
            "article_url": article_url,
            "title": title,
            "date": date,
            "image": img,
            "writer": writer
        })

# %%
df = pd.DataFrame(all_articles)
df.to_csv("fanabc_news.csv", index=False)
print(df.head())
# Out:
#    category                                         source_url  \
# 0  Business  https://www.fanabc.com/english/category/business/
# 1  Business  https://www.fanabc.com/english/category/business/
# 2  Business  https://www.fanabc.com/english/category/business/
# 3  Business  https://www.fanabc.com/english/category/business/
# 4  Business  https://www.fanabc.com/english/category/business/
#
#                                          article_url  \
# 0  https://www.fanamc.com/english/midroc-ethiopia...
# 1  https://www.fanamc.com/english/made-in-ethiopi...
# 2  https://www.fanamc.com/english/ethiopian-airli...
# 3  https://www.fanamc.com/english/investment-refo...
# 4  https://www.fanamc.com/english/norwegian-inves...
#
#                                                title date image writer
# 0  MIDROC Ethiopia, IFC Sign $80 Million Deal to ...
# 1  “Made in Ethiopia” Movement Key to Advancing E...
# 2  Ethiopian Airlines and CBE Launch Co-Branded V...
# 3  Investment, Reform, and Market Access: Ethiopi...
# 4  Norwegian Investors Eye Ethiopia’s E-Mobility ...
