# %% [markdown]
# Removing rows

# %%
import pandas as pd
# Sample dataset
data = {'ID': ['Eth - 101', 'Eth - 102', 'Eth - 103', 'Eth - 104', 'Eth - 105', 'Eth - 102', 'Eth - 104', 'Eth - 106'],
    'Name': ['Haileslassie Zeferu Abel', 'Worku Abenezer Girma', 'Abenezer Reta Tamirat', 'Abraham Melisew Fireda', 'Hailu Abraham Niguse', 
             'Worku, Abenezer Girma', 'Abraham Melisew Fireda', 'Hailu Abraham Niguse'],
    'Age': [25, 29, 29, 33, 29, 29, 33, 29],
    'Salary': [55000, 48000, 55000, 62000, 55000, 48000, 62000, 55000],
    'City': ['Addis Ababa', 'Adama', 'Addis Ababa', 'Adama', 'Addis Ababa', 'Adama', 'Adama', 'Addis Ababa']}
# Original Dataset
df = pd.DataFrame(data)
print("Original Dataset")
print(df, '\n')
# Out:
# Original Dataset
#           ID                      Name  Age  Salary         City
# 0  Eth - 101  Haileslassie Zeferu Abel   25   55000  Addis Ababa
# 1  Eth - 102      Worku Abenezer Girma   29   48000        Adama
# 2  Eth - 103     Abenezer Reta Tamirat   29   55000  Addis Ababa
# 3  Eth - 104    Abraham Melisew Fireda   33   62000        Adama
# 4  Eth - 105      Hailu Abraham Niguse   29   55000  Addis Ababa
# 5  Eth - 102     Worku, Abenezer Girma   29   48000        Adama
# 6  Eth - 104    Abraham Melisew Fireda   33   62000        Adama
# 7  Eth - 106      Hailu Abraham Niguse   29   55000  Addis Ababa

# %%
# Exact Match - based on all columns
df_cleaned = df.drop_duplicates()
print("Duplicates Removed - Exact Match")
print(df_cleaned, '\n')
# Out:
# Duplicates Removed - Exact Match
#           ID                      Name  Age  Salary         City
# 0  Eth - 101  Haileslassie Zeferu Abel   25   55000  Addis Ababa
# 1  Eth - 102      Worku Abenezer Girma   29   48000        Adama
# 2  Eth - 103     Abenezer Reta Tamirat   29   55000  Addis Ababa
# 3  Eth - 104    Abraham Melisew Fireda   33   62000        Adama
# 4  Eth - 105      Hailu Abraham Niguse   29   55000  Addis Ababa
# 5  Eth - 102     Worku, Abenezer Girma   29   48000        Adama
# 7  Eth - 106      Hailu Abraham Niguse   29   55000  Addis Ababa

# %%
# Partial Match - based on specific columns only (e.g., 'ID')
df_cleaned_id = df.drop_duplicates(subset=['ID'])
print("Duplicates Removed - Partial Match based on ID")
print(df_cleaned_id, '\n')
# Out:
# Duplicates Removed - Partial Match based on ID
#           ID                      Name  Age  Salary         City
# 0  Eth - 101  Haileslassie Zeferu Abel   25   55000  Addis Ababa
# 1  Eth - 102      Worku Abenezer Girma   29   48000        Adama
# 2  Eth - 103     Abenezer Reta Tamirat   29   55000  Addis Ababa
# 3  Eth - 104    Abraham Melisew Fireda   33   62000        Adama
# 4  Eth - 105      Hailu Abraham Niguse   29   55000  Addis Ababa
# 7  Eth - 106      Hailu Abraham Niguse   29   55000  Addis Ababa

# %%
# Partial Match - based on specific columns only (e.g., 'ID')
df_cleaned_name = df.drop_duplicates(subset=['Name'])
print("Duplicates Removed - Partial Match based on Name")
print(df_cleaned_name, '\n')
# Out:
# Duplicates Removed - Partial Match based on Name
#           ID                      Name  Age  Salary         City
# 0  Eth - 101  Haileslassie Zeferu Abel   25   55000  Addis Ababa
# 1  Eth - 102      Worku Abenezer Girma   29   48000        Adama
# 2  Eth - 103     Abenezer Reta Tamirat   29   55000  Addis Ababa
# 3  Eth - 104    Abraham Melisew Fireda   33   62000        Adama
# 4  Eth - 105      Hailu Abraham Niguse   29   55000  Addis Ababa
# 5  Eth - 102     Worku, Abenezer Girma   29   48000        Adama

# %%
# Partial Match - based on specific columns only (e.g., 'ID' and 'Name')
df_cleaned_specific = df.drop_duplicates(subset=['ID', 'Name'])
print("Duplicates Removed - Partial Match based on ID and Name")
print(df_cleaned_specific, '\n')

# %% [markdown]
# # Remove rows with missing values
# df_cleaned = df.dropna()
# print(df_cleaned)

# %%
import pandas as pd
# Create the dataset
data = {'ID': ['Eth - 101', 'Eth – 102', 'Eth - 103', 'Eth - 104', 'Eth - 105'],
        'Name': [' Haileslassie Zeferu Abel', ' Worku Abenezer Girma', ' Abenezer Reta Tamirat', ' Abraham Melisew Fireda', ' Hailu Abraham Niguse'],

        'Age': [25, None, 29, 33, None],
        'Salary': [55000, 48000, None, 62000, None]}

df = pd.DataFrame(data)
print(df)
# Out:
#           ID                       Name   Age   Salary
# 0  Eth - 101   Haileslassie Zeferu Abel  25.0  55000.0
# 1  Eth – 102       Worku Abenezer Girma   NaN  48000.0
# 2  Eth - 103      Abenezer Reta Tamirat  29.0      NaN
# 3  Eth - 104     Abraham Melisew Fireda  33.0  62000.0
# 4  Eth - 105       Hailu Abraham Niguse   NaN      NaN

# %% [markdown]
# Remove rows with missing values

# %%
df_cleaned = df.dropna()
print(df_cleaned)
# Out:
#           ID                       Name   Age   Salary
# 0  Eth - 101   Haileslassie Zeferu Abel  25.0  55000.0
# 3  Eth - 104     Abraham Melisew Fireda  33.0  62000.0

# %% [markdown]
# Imputation

# %%
# Create the dataset agian
data = {'ID': ['Eth - 101', 'Eth – 102', 'Eth - 103', 'Eth - 104', 'Eth - 105'],
        'Name': [' Haileslassie Zeferu Abel', ' Worku Abenezer Girma', ' Abenezer Reta Tamirat', ' Abraham Melisew Fireda', ' Hailu Abraham Niguse'],

        'Age': [25, None, 29, 33, None],
        'Salary': [55000, 48000, None, 62000, None]}

df = pd.DataFrame(data)
print(df)
# Out:
#           ID                       Name   Age   Salary
# 0  Eth - 101   Haileslassie Zeferu Abel  25.0  55000.0
# 1  Eth – 102       Worku Abenezer Girma   NaN  48000.0
# 2  Eth - 103      Abenezer Reta Tamirat  29.0      NaN
# 3  Eth - 104     Abraham Melisew Fireda  33.0  62000.0
# 4  Eth - 105       Hailu Abraham Niguse   NaN      NaN

# %%
for column in df.columns:
    if df[column].dtype == 'float64' or df[column].dtype == 'int64':
        df[column].fillna(df[column].mean(), inplace=True)
print(df)
# Out:
#           ID                       Name   Age   Salary
# 0  Eth - 101   Haileslassie Zeferu Abel  25.0  55000.0
# 1  Eth – 102       Worku Abenezer Girma  29.0  48000.0
# 2  Eth - 103      Abenezer Reta Tamirat  29.0  55000.0
# 3  Eth - 104     Abraham Melisew Fireda  33.0  62000.0
# 4  Eth - 105       Hailu Abraham Niguse  29.0  55000.0
# C:\Users\ISUG\AppData\Local\Temp\ipykernel_23348\1517066591.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(df[column].mean(), inplace=True)

# %%
# Create the dataset agian
data = {'ID': ['Eth - 101', 'Eth – 102', 'Eth - 103', 'Eth - 104', 'Eth - 105'],
        'Name': [' Haileslassie Zeferu Abel', ' Worku Abenezer Girma', ' Abenezer Reta Tamirat', ' Abraham Melisew Fireda', ' Hailu Abraham Niguse'],

        'Age': [25, None, 29, 33, None],
        'Salary': [55000, 48000, None, 62000, None]}

df = pd.DataFrame(data)
print(df)
# Out:
#           ID                       Name   Age   Salary
# 0  Eth - 101   Haileslassie Zeferu Abel  25.0  55000.0
# 1  Eth – 102       Worku Abenezer Girma   NaN  48000.0
# 2  Eth - 103      Abenezer Reta Tamirat  29.0      NaN
# 3  Eth - 104     Abraham Melisew Fireda  33.0  62000.0
# 4  Eth - 105       Hailu Abraham Niguse   NaN      NaN

# %%
for column in df.columns:
    if df[column].isnull().any():
        df[f'{column}_Flag'] = df[column].isna().apply(lambda x: 'Missing'
if x else 'Not Missing')
# Create a row-based flag
df['Missing_Flag'] = df.isnull().any(axis=1).apply(lambda x: 'Missing' if x
else 'Not Missing')

# %% [markdown]
# Flagging

# %%
import pandas as pd

# Create the dataset again
data = {
    'ID': ['Eth - 101', 'Eth - 102', 'Eth - 103', 'Eth - 104', 'Eth - 105'],
    'Name': [
        'Haileslassie Zeferu Abel',
        'Worku Abenezer Girma',
        'Abenezer Reta Tamirat',
        'Abraham Melisew Fireda',
        'Hailu Abraham Niguse'
    ],
    'Age': [25, None, 29, 33, None],
    'Salary': [55000, 48000, None, 62000, None]
}

df = pd.DataFrame(data)

print(df)

# Create column-based flags
for column in df.columns:
    if df[column].isnull().any():
        df[f'{column}_Flag'] = df[column].isna().apply(
            lambda x: 'Missing' if x else 'Not Missing'
        )

# Create row-based flag
df['Missing_Flag'] = df.isnull().any(axis=1).apply(
    lambda x: 'Missing' if x else 'Not Missing'
)

print(df)
# Out:
#           ID                      Name   Age   Salary
# 0  Eth - 101  Haileslassie Zeferu Abel  25.0  55000.0
# 1  Eth - 102      Worku Abenezer Girma   NaN  48000.0
# 2  Eth - 103     Abenezer Reta Tamirat  29.0      NaN
# 3  Eth - 104    Abraham Melisew Fireda  33.0  62000.0
# 4  Eth - 105      Hailu Abraham Niguse   NaN      NaN
#           ID                      Name   Age   Salary     Age_Flag  \
# 0  Eth - 101  Haileslassie Zeferu Abel  25.0  55000.0  Not Missing
# 1  Eth - 102      Worku Abenezer Girma   NaN  48000.0      Missing
# 2  Eth - 103     Abenezer Reta Tamirat  29.0      NaN  Not Missing
# 3  Eth - 104    Abraham Melisew Fireda  33.0  62000.0  Not Missing
# 4  Eth - 105      Hailu Abraham Niguse   NaN      NaN      Missing
#
#    Salary_Flag Missing_Flag
# 0  Not Missing  Not Missing
# 1  Not Missing      Missing
# 2      Missing      Missing
# 3  Not Missing  Not Missing
# 4      Missing      Missing

# %%
import pandas as pd
from dateutil.parser import parse
# Sample data

55

data = {
    'Event ID': ['E-001', 'E-002', 'E-003', 'E-004', 'E-005'],
    'Event Date': ['01/12/2023', 'December 2, 2023', '2023-12-03', '12.04.2023', '5th Dec 2023'],
    'Product Name': ['apple', 'Banana', 'ORANGE', 'BaNAna', 'Apple'],
    'Weight' : ['70 kg', '100 lbs', '88 KG', '180 pound', '94 kilograms']
}
df = pd.DataFrame(data)
print("Original Dataset")
print(df, '\n')

# %%
print(df.columns.tolist())
# Out:
# ['ID', 'Name', 'Age', 'Salary', 'Age_Flag', 'Salary_Flag', 'Missing_Flag']

# %%
df = pd.DataFrame(data)

# Create the function
def parse_date(date_str):
    try:
        return parse(date_str, dayfirst=False)
    except ValueError:
        return pd.NaT

# Apply the function
df['Event Date'] = df['Event Date'].apply(parse_date)

# Standardize the format
df['Event Date'] = df['Event Date'].dt.strftime('%Y-%m-%d')

print(df)
# Out:
#   Event ID  Event Date Product Name        Weight
# 0    E-001  2023-01-12        apple         70 kg
# 1    E-002  2023-12-02       Banana       100 lbs
# 2    E-003  2023-12-03       ORANGE         88 KG
# 3    E-004  2023-12-04       BaNAna     180 pound
# 4    E-005  2023-12-05        Apple  94 kilograms

# %%
df = pd.DataFrame(data)
# Convert 'Product Name' to lowercase
df['Product Name'] = df['Product Name'].str.lower()
print(df)
# Out:
#   Event ID        Event Date Product Name        Weight
# 0    E-001        01/12/2023        apple         70 kg
# 1    E-002  December 2, 2023       banana       100 lbs
# 2    E-003        2023-12-03       orange         88 KG
# 3    E-004        12.04.2023       banana     180 pound
# 4    E-005      5th Dec 2023        apple  94 kilograms

# %%
df = pd.DataFrame(data)
# Extract numeric value and unit
df['Numeric Value'] = df['Weight'].str.extract(r'(\d+\.?\d*)').astype(float)
# Use str to convert the extracted unit to lowercase
df['Unit'] = df['Weight'].str.extract(r'([a-zA-Z]+)')[0].str.lower() # Access the first element of the returned DataFrame, which is a Series
# Conversion function
def convert_to_kg(row):
    if row['Unit'] in ['kg', 'kilograms']:
        return row['Numeric Value']
    elif row['Unit'] in ['lbs', 'pound']:
        return row['Numeric Value'] * 0.453592
    else:
        return None # or handle unknown units
df['Weight in kg'] = df.apply(convert_to_kg, axis=1)
print(df[['Event ID', 'Weight', 'Weight in kg']])
# Out:
#   Event ID        Weight  Weight in kg
# 0    E-001         70 kg      70.00000
# 1    E-002       100 lbs      45.35920
# 2    E-003         88 KG      88.00000
# 3    E-004     180 pound      81.64656
# 4    E-005  94 kilograms      94.00000

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = {'Person ID': range(1, 13),
'Full Name': ['Haileslassie Zeferu Abel', 'Worku Abenezer Girma', 'Abenezer Reta Tamirat', 'Abraham Melisew Fireda', 'Hailu Abraham Niguse', 'Weldetinsae Adonay Gebrehiwot ', 'Debebe Gebremeskel Akin', 'Teferi Amanuel Abebaw', 'Muche Amaniel Kahsu', 'Amanuel Degulaw Zerga', 'Amanuel Abate Nega', 'Amanuel Solomon Hailu'],
'Income': [80000, 95000, 115000, 75000, 110000, 85000, 100000, 199000,105000, 90000, 80000, 95000]
}
df = pd.DataFrame(data)

# %%
#box plot
plt.figure(figsize=(8, 4))
plt.boxplot(df['Income'], vert=False, showfliers=True)
plt.title('Box Plot of Incomes')
plt.xlabel('Income ($000)')
plt.show()

# %%
# Scatter Plot
plt.figure(figsize=(8, 4))
plt.scatter(df['Person ID'], df['Income'])
plt.title('Scatter Plot of Incomes')
plt.xlabel('Person ID')
plt.ylabel('Income ($000)')
plt.show()

# %%
df = pd.DataFrame(data)
# Calculate Q1, Q3, bounds and Identify outliers
Q1 = df['Income'].quantile(0.25)
Q3 = df['Income'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df['Outlier'] = df['Income'].apply(
    lambda x: 'Outlier' if x > upper_bound else 'Normal')
print(df)
# Out:
#     Person ID                       Full Name  Income  Outlier
# 0           1        Haileslassie Zeferu Abel   80000   Normal
# 1           2            Worku Abenezer Girma   95000   Normal
# 2           3           Abenezer Reta Tamirat  115000   Normal
# 3           4          Abraham Melisew Fireda   75000   Normal
# 4           5            Hailu Abraham Niguse  110000   Normal
# 5           6  Weldetinsae Adonay Gebrehiwot    85000   Normal
# 6           7         Debebe Gebremeskel Akin  100000   Normal
# 7           8           Teferi Amanuel Abebaw  199000  Outlier
# 8           9             Muche Amaniel Kahsu  105000   Normal
# 9          10           Amanuel Degulaw Zerga   90000   Normal
# 10         11              Amanuel Abate Nega   80000   Normal
# 11         12           Amanuel Solomon Hailu   95000   Normal
